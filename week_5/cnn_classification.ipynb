# %% [markdown]
# ## Классификация при помощи CNN.
# На занятии по классификации временных рядов мы разобрали подход, основанный на мере расстояния DTW. Другое семейство алгоритмов основано на вычислении признаков по скользящему окну, например, автоматическая генерация признаков при помощи CNN. В задании вам предлагается разработать baseline решение для классификации рядов из датасета human activity recognition (https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones) при помощи CNN сети. В качестве базовой архитектуры будем использовать наработки с семинара по предсказанию при помощи CNN, где в последнем слое используется softmax в качестве функции активации.

# %%
from typing import Tuple

# %%
import numpy as np
import pandas as pd
import keras
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### 1. Считаем данные
# - Фичи сразу решейпнем, добавив размерность для свёрточного слоя
# - Лейблы принимают значения от 1 до 6. Для корректного расчёта моделью мы отнимем от ниx 1 (превратим в range(6)) и заэнкодим в категориальный таргет.

# %%
def read_data(train_or_test: str) -> Tuple[np.array, np.array]:
    a = []
    with open(f'../data/UCI_HAR_dataset/{train_or_test}/X_{train_or_test}.txt', 'r') as f:
        for line in f:
            a.append([float(i) for i in line.strip().split()])

    X = np.vstack(a)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    y = to_categorical(
        np.loadtxt(f'../data/UCI_HAR_dataset/{train_or_test}/y_{train_or_test}.txt', delimiter=' ') - 1
    )
    
    return X, y

# %%
X_train, y_train = read_data('train')
X_test, y_test = read_data('test')

# %%
y_test.shape
# Out:
# (2947, 6)

# %%
y_train.shape
# Out:
# (7352, 6)

# %%
pd.Series(X_train[0].flatten()).plot()
pd.Series(X_train[1].flatten()).plot()
pd.Series(X_train[2].flatten()).plot()
# Out:
# <Axes: >

# %%
y_train[1], y_train[2], y_train[5000]
# Out:
# (array([0., 0., 0., 0., 1., 0.], dtype=float32),
#  array([0., 0., 0., 0., 1., 0.], dtype=float32),
#  array([1., 0., 0., 0., 0., 0.], dtype=float32))

# %%
X_train.shape
# Out:
# (7352, 561, 1)

# %% [markdown]
# ### 2. Постройте базовую CNN модель.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/technogleb/ts_march_2024/.env/lib/python3.10/site-packages (4.66.2)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/technogleb/ts_march_2024/.env/bin/python -m pip install --upgrade pip' command.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D, Dropout
from tensorflow.keras.callbacks import Callback
from tqdm.notebook import tqdm

# %% [markdown]
# 1. Задайте модель Sequential
# 2. Добавьте входной сверточный слой Conv1D (укажите нужный input_shape)
# 3. Добавьте слой Flatten, чтобы можно было передать выход со сверточного слоя на вход полносвязному
# 4. Добавьте полносвязный слой с софтмаксом
# 5. Соберите модель, в качестве метода оптимизации укажите adam, в качестве функции потерь категориальную кроссэнтропию.
# 6. Обучите модель
# 7. Сделайте прогноз и выведите classification_report

# %%
# your code here

# %%
# your code here
# Out:
# Epoch 1/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3153
# Epoch 2/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0969
# Epoch 3/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0697
# Epoch 4/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0526
# Epoch 5/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0510
# Epoch 6/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0504
# Epoch 7/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0338
# Epoch 8/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0293
# Epoch 9/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0341
# Epoch 10/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0265
# Epoch 11/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0248
# Epoch 12/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0251
# Epoch 13/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0269
# Epoch 14/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0210
# Epoch 15/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0183
# Epoch 16/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0184
# Epoch 17/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0202
# Epoch 18/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0154
# Epoch 19/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0169
# Epoch 20/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0127
# Epoch 21/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 22/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 23/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0110
# Epoch 24/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0076
# Epoch 25/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0071
# Epoch 26/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0327
# Epoch 27/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0207
# Epoch 28/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0073
# Epoch 29/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 30/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0039
# Epoch 31/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0022
# Epoch 32/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0026
# Epoch 33/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0019
# Epoch 34/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0042
# Epoch 35/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0053
# Epoch 36/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0167
# Epoch 37/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0144
# Epoch 38/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0028
# Epoch 39/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0034
# Epoch 40/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.3048e-04
# Epoch 41/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.2295e-04
# Epoch 42/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0034
# Epoch 43/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0151
# Epoch 44/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0033
# Epoch 45/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.4913e-04
# Epoch 46/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.9234e-04
# Epoch 47/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.0793e-04
# Epoch 48/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.8973e-04
# Epoch 49/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.5280e-04
# Epoch 50/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.2915e-04
# Epoch 51/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.0064e-04
# Epoch 52/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.7083e-04
# Epoch 53/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5375e-04
# Epoch 54/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.7784e-04
# Epoch 55/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2737e-04
# Epoch 56/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5933e-04
# Epoch 57/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1401e-04
# Epoch 58/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1314e-04
# Epoch 59/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.6096e-05
# Epoch 60/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.9433e-05
# Epoch 61/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0699e-04
# Epoch 62/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0439
# Epoch 63/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0143
# Epoch 64/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0063
# Epoch 65/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0025
# Epoch 66/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0011
# Epoch 67/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.6334e-04
# Epoch 68/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.8686e-04
# Epoch 69/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1683e-04
# Epoch 70/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1104e-04
# Epoch 71/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.6255e-04
# Epoch 72/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.2459e-04
# Epoch 73/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8520e-04
# Epoch 74/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5459e-04
# Epoch 75/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4184e-04
# Epoch 76/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2984e-04
# Epoch 77/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1875e-04
# Epoch 78/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0241e-04
# Epoch 79/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0723e-04
# Epoch 80/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1580e-04
# Epoch 81/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.4455e-05
# Epoch 82/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.6703e-05
# Epoch 83/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.5064e-05
# Epoch 84/100
# 230/230 [==============================] - 1s 4ms/step - loss: 6.7435e-05
# Epoch 85/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0417
# Epoch 86/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0084
# Epoch 87/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0023
# Epoch 88/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0014
# Epoch 89/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.5534e-04
# Epoch 90/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1336e-04
# Epoch 91/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.3210e-04
# Epoch 92/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.0904e-04
# Epoch 93/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.7470e-04
# Epoch 94/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8021e-04
# Epoch 95/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4853e-04
# Epoch 96/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.3143e-04
# Epoch 97/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1906e-04
# Epoch 98/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0641e-04
# Epoch 99/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0555e-04
# Epoch 100/100
# 230/230 [==============================] - 1s 4ms/step - loss: 8.4381e-05

# %% [markdown]
# ### 3. Попробуйте добавить дополнительный свероточный слой, MaxPooling, и пару промежуточных полносвязный слоев.

# %%
# your code here

# %%
# your code here

# %%
from sklearn.metrics import classification_report

# your code here

# %% [markdown]
# ### 4. Попробуйте сравнить качество с базовым dtw, используя fastdtw.

# %%
import fastdtw
fastdtw.fastdtw
# Out:
# <function fastdtw._fastdtw.fastdtw>

# %% [markdown]
# #### Напишите функцию get_label, возвращающую соответсвующий класс для ряда из X_test
# * принимает на вход ряд из X_test
# * проходится по всем рядам из X_train
# * считает dtw
# * возвращает y из y_train, соответвующий минимальному dtw

# %%
def get_label(ts_test: np.array) -> np.array:
    # your code here
    ...

# %% [markdown]
# #### Пройдитесь по 50-100 рядам из X_test (примерное время 5-15 минут) и оцените точность классификации

# %%
# your code here
